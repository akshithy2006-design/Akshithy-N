# %%
# %pip install numpy
# %pip install pandas
# %pip install matplotlib
# %pip install seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"student performance result 2.csv")

# %%
df.head()
# Out:
#    S.No Student Name       Class  Tamil  English  Maths  Science  Social  \
# 0     1     Dharani    II BSc CS     94       43     67       87      61
# 1     2        Esha   III BSc CS     61       40     78       63      63
# 2     3      Aakash    II BSc CS    100       68     87      100      96
# 3     4       Indhu   III BSc CS     86       47     42       67      94
# 4     5     Krishna   III BSc CS     88       93     68       79      49
#
#    Total  Average Grade Status
# 0    352     70.4     B   Pass
# 1    305     61.0     C   Pass
# 2    451     90.2    A+   Pass
# 3    336     67.2     C   Pass
# 4    377     75.4     B   Pass

# %%
df.shape
# Out:
# (500, 12)

# %%
df.columns
# Out:
# Index(['S.No', 'Student Name', 'Class', 'Tamil', 'English', 'Maths', 'Science',
#        'Social', 'Total', 'Average', 'Grade', 'Status'],
#       dtype='object')

# %%
df.dtypes
# Out:
# S.No              int64
# Student Name     object
# Class            object
# Tamil             int64
# English           int64
# Maths             int64
# Science           int64
# Social            int64
# Total             int64
# Average         float64
# Grade            object
# Status           object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   S.No          500 non-null    int64
#  1   Student Name  500 non-null    object
#  2   Class         500 non-null    object
#  3   Tamil         500 non-null    int64
#  4   English       500 non-null    int64
#  5   Maths         500 non-null    int64
#  6   Science       500 non-null    int64
#  7   Social        500 non-null    int64
#  8   Total         500 non-null    int64
#  9   Average       500 non-null    float64
#  10  Grade         500 non-null    object
#  11  Status        500 non-null    object
# dtypes: float64(1), int64(7), object(4)
# memory usage: 47.0+ KB

# %%
df.replace(r'^\s*$',np.nan,regex=True,inplace=True)
df.isnull()
df.head()
# Out:
#    S.No Student Name       Class  Tamil  English  Maths  Science  Social  \
# 0     1     Dharani    II BSc CS     94       43     67       87      61
# 1     2        Esha   III BSc CS     61       40     78       63      63
# 2     3      Aakash    II BSc CS    100       68     87      100      96
# 3     4       Indhu   III BSc CS     86       47     42       67      94
# 4     5     Krishna   III BSc CS     88       93     68       79      49
#
#    Total  Average Grade Status
# 0    352     70.4     B   Pass
# 1    305     61.0     C   Pass
# 2    451     90.2    A+   Pass
# 3    336     67.2     C   Pass
# 4    377     75.4     B   Pass

# %%
df.isnull().sum()
# Out:
# S.No            0
# Student Name    0
# Class           0
# Tamil           0
# English         0
# Maths           0
# Science         0
# Social          0
# Total           0
# Average         0
# Grade           0
# Status          0
# dtype: int64

# %%
import pandas as pd
df = pd.read_csv("student performance result 2.csv")

# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt

# ---------------------------------
# Read Data from CSV File
# ---------------------------------
df = pd.read_csv('student performance result 2.csv')

print("\nOriginal Dataset")
print(df)

# ---------------------------------
# Calculate Total and Average
# ---------------------------------
subjects = ['Tamil', 'English', 'Maths', 'Science','Social']

df['Total'] = df[subjects].sum(axis=1)
df['Average'] = df[subjects].mean(axis=1)

# ---------------------------------
# Assign Grade
# ---------------------------------
def assign_grade(avg):
    if avg >= 90:
        return 'A+'
    elif avg >= 80:
        return 'A'
    elif avg >= 70:
        return 'B'
    elif avg >= 60:
        return 'C'
    else:
        return 'Fail'

df['Grade'] = df['Average'].apply(assign_grade)

# ---------------------------------
# Pass/Fail Status
# ---------------------------------
df['Status'] = df[subjects].apply(
    lambda x: 'Pass' if all(mark >= 50 for mark in x) else 'Fail',
    axis=1
)

print("\nStudent Performance Report")
print(df)
# Out:
# Original Dataset
#      S.No Student Name       Class  Tamil  English  Maths  Science  Social  \
# 0       1     Dharani    II BSc CS     94       43     67       87      61
# 1       2        Esha   III BSc CS     61       40     78       63      63
# 2       3      Aakash    II BSc CS    100       68     87      100      96
# 3       4       Indhu   III BSc CS     86       47     42       67      94
# 4       5     Krishna   III BSc CS     88       93     68       79      49
# ..    ...          ...         ...    ...      ...    ...      ...     ...
# 495   496     Bhavana     I BSc CS     83       94     70       51      94
# 496   497      Dinesh     I BSc CS     55       53     78       85      54
# 497   498      Janani   III BSc CS     79       80     77       65      79
# 498   499      Anitha    II BSc CS     63       39     87       71      54
# 499   500       Ishaan   II BSc CS     59       90     60       65      54
#
#      Total  Average Grade Status
# ...

# %%
# ---------------------------------
# Subject-wise Performance
# ---------------------------------
subject_avg = df[subjects].mean()

print("\nSubject-wise Average Marks")
print(subject_avg)

# ---------------------------------
# Class-wise Comparison
# ---------------------------------
class_avg = df.groupby('Class')[subjects].mean()

print("\nClass-wise Performance")
print(class_avg)

# ---------------------------------
# Save Processed Results
# ---------------------------------
df.to_csv('student_result_report.csv', index=False)
print("\nProcessed report saved as 'student_result_report.csv'")

# ---------------------------------
# Chart 1: Subject-wise Average
# ---------------------------------
plt.figure(figsize=(7,5))
subject_avg.plot(kind='bar')
plt.title('Subject-wise Average Marks')
plt.ylabel('Marks')
plt.xticks(rotation=0)
plt.show()
# Out:
# Subject-wise Average Marks
# Tamil      67.112
# English    66.816
# Maths      67.906
# Science    67.076
# Social     68.604
# dtype: float64
#
# Class-wise Performance
#                 Tamil    English      Maths    Science     Social
# Class
# I BSc CS    67.632911  66.183544  68.873418  67.531646  67.784810
# II BSc CS   67.528409  68.153409  67.284091  66.528409  69.954545
# III BSc CS  66.174699  66.000000  67.644578  67.222892  67.951807
#
# Processed report saved as 'student_result_report.csv'

# %%
# Chart 3: Pass vs Fail
# ---------------------------------
status_count = df['Status'].value_counts()

plt.figure(figsize=(6,6))
plt.pie(status_count,
        labels=status_count.index,
        autopct='%1.1f%%')
plt.title('Pass vs Fail Distribution')
plt.show()

# %%
# Chart 4: Class-wise Comparison
# ---------------------------------
class_avg.plot(kind='bar', figsize=(8,5))
plt.title('Class-wise Subject Comparison')
plt.ylabel('Average Marks')
plt.xticks(rotation=0)
plt.show()
